# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
data = pd.read_csv('https://covid.ourworldindata.org/data/ecdc/full_data.csv')
data
# Out:
#             date     location  new_cases  new_deaths  total_cases  \
# 0     2019-12-31  Afghanistan          0           0            0
# 1     2020-01-01  Afghanistan          0           0            0
# 2     2020-01-02  Afghanistan          0           0            0
# 3     2020-01-03  Afghanistan          0           0            0
# 4     2020-01-04  Afghanistan          0           0            0
# ...          ...          ...        ...         ...          ...
# 6447  2020-03-22       Zambia          0           0            2
# 6448  2020-03-23       Zambia          1           0            3
# 6449  2020-03-21     Zimbabwe          1           0            1
# 6450  2020-03-22     Zimbabwe          1           0            2
# 6451  2020-03-23     Zimbabwe          0           0            2
#
#       total_deaths
# 0                0
# 1                0
# 2                0
# 3                0
# 4                0
# ...            ...
# 6447             0
# ...

# %%
def plot_new_cases(loc, ax=None):
    if ax is None:
        ax = plt.gca()
    data[data["location"] == loc].plot(x='date', y='new_cases', marker='.', ax=ax, label=loc)

ax = plt.gca()
plot_new_cases("Germany", ax=ax)
plot_new_cases("Netherlands", ax=ax)
plot_new_cases("Austria", ax=ax)

ax.set_ylabel('new cases');
